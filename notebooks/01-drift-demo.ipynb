# %% [markdown]
# # Post-earnings announcement drift
#
# The readable walkthrough. Empty for now: the repo is only set up.
# The earnings-surprise collector is the next step of `TODO.md`, and its
# output is what this notebook will display.
#
# Setup, from the repo root:
#
# ```bash
# python3 -m venv .venv
# source .venv/bin/activate
# pip install -r requirements.txt
# pip install -e .
# ```

# %%
import drift

drift.__version__
